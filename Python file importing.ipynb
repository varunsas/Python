# %% [markdown]
# ## Reading excel file ##

# %%
import pandas as pd

# %%
file= pd.ExcelFile("C:\\Users\\HP\\Desktop\\Test.xls")

# %%
file.sheet_names
# Out:
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
df1= file.parse('Sheet1')

# %%
df2= file.parse('Sheet2')

# %%
df1.head()
# Out:
#      BU  Age   Q1   Q2   Q3   Q4   Q5
# 0   2.0  3.0  1.0  3.0  3.0  5.0  1.0
# 1   2.0  2.0  2.0  1.0  3.0  5.0  1.0
# 2   9.0  4.0  3.0  6.0  5.0  2.0  2.0
# 3  10.0  1.0  4.0  1.0  3.0  6.0  1.0
# 4   7.0  3.0  5.0  1.0  1.0  3.0  3.0

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.tail()
# Out:
#        BU  Age   Q1   Q2   Q3   Q4   Q5
# 494   7.0  1.0  1.0  1.0  6.0  2.0  3.0
# 495   3.0  3.0  6.0  3.0  2.0  4.0  1.0
# 496  10.0  4.0  3.0  3.0  3.0  1.0  5.0
# 497   3.0  4.0  4.0  6.0  6.0  1.0  4.0
# 498   9.0  4.0  1.0  5.0  3.0  6.0  6.0

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1=file.parse(0)

# %%
df1.head()
# Out:
#      BU  Age   Q1   Q2   Q3   Q4   Q5
# 0   2.0  3.0  1.0  3.0  3.0  5.0  1.0
# 1   2.0  2.0  2.0  1.0  3.0  5.0  1.0
# 2   9.0  4.0  3.0  6.0  5.0  2.0  2.0
# 3  10.0  1.0  4.0  1.0  3.0  6.0  1.0
# 4   7.0  3.0  5.0  1.0  1.0  3.0  3.0

# %%
df3= file.parse(1)

# %%
df3.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

# %%
file=  pd.ExcelFile("C:\\Users\\HP\\Desktop\\SAS Test.xlsx")

# %%
file.sheet_names
# Out:
# ['Problems', 'Table1', 'Table2', 'Table3']

# %%
Df4= file.parse(1)

# %%
Df5= file.parse(2)

# %%
Df6= file.parse(3)

# %%
Df4.head()
# Out:
#    AgreementNo  UCID  Age  Income     Occupation
# 0        11001   100   57   63217  Self Employed
# 1        11002   101   43   81355  Self Employed
# 2        11003   102   52   48059       Self'Emp
# 3        11004   103   43   33009       Salaried
# 4        11005   104   27   55531       Salaried

# %%
Df5.head()
# Out:
#   Agreement_No  DPD       Date  Principal Billed  Principal Received  \
# 0        11001   58 2017-01-31            1999.0              1030.0
# 1        11002   33 2017-01-31            1230.0              1130.0
# 2        11003   42 2017-01-31            1359.0              1588.0
# 3        11004   67 2017-01-31            1056.0              1643.0
# 4        11005   26 2017-01-31            1977.0              1671.0
#
#    Interest Billed  Interest Received
# 0              931               1295
# 1             1798                249
# 2             1103                174
# 3              884               1521
# 4              611                 83

# %%
Df6.head()
# Out:
#    AgreementNo       City
# 0        11001    Kolkata
# 1        11002     Mumbai
# 2        11003      Delhi
# 3        11004  Bangalore
# 4        11005  Hyderabad

# %%
import pandas as pd

# %%
file1= pd.ExcelFile("C:\\Users\\HP\\Desktop\\SAS Test.xlsx")

# %%
file1.sheet_names
# Out:
# ['Problems', 'Table1', 'Table2', 'Table3']

# %%
DF7= file.parse("Table1")

# %%
DF8= file.parse("Table2")

# %%
DF9= file.parse("Table3")

# %%
DF7.tail()
# Out:
#     AgreementNo  UCID  Age  Income     Occupation
# 46        11047   108   46   88204       Self'Emp
# 47        11048   109   55   44237  Self Employed
# 48        11049   110   57   67990       Self'Emp
# 49        11050   111   29   53777       Salaried
# 50        11051   112   57   28431  Self Employed

# %%
DF8.tail()
# Out:
#     Agreement_No  DPD       Date  Principal Billed  Principal Received  \
# 607        11047   56 2017-12-31            1681.0              1956.0
# 608        11048   86 2017-12-31            1189.0              1144.0
# 609        11049   31 2017-12-31            1829.0              1023.0
# 610        11050   31 2017-12-31            1021.0              1134.0
# 611         AAAA   73 2017-12-31            1669.0              1321.0
#
#      Interest Billed  Interest Received
# 607              464                237
# 608             1186                535
# 609              329                457
# 610             1189               1382
# 611              714                741

# %%
DF9.tail()
# Out:
#     AgreementNo     City
# 68        11018   Kerala
# 69        11019   Kerela
# 70        11020  Kolkata
# 71        11021   Mumbai
# 72        11022   Nagpur

# %% [markdown]
# ## Reading Flat File ##

# %% [markdown]
# ### numpy #

# %%
import numpy as np

# %% [markdown]
# mnist_data= np.loadtxt("C:\\Users\\HP\\Desktop\\Titanic1.csv", dtype= None, delimiter=',',comments='#')

# %%
titanic_data=np.genfromtxt("C:\\Users\\HP\\Desktop\\Titanic1.csv",dtype=None,delimiter=',',skip_header=1)

# %% [markdown]
# titanic_data.view()

# %%
titanic_data.shape
# Out:
# (200,)

# %%
titanic_data.size
# Out:
# 200

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\HP\\Desktop\\Titanic1.csv",sep=',')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Unnamed: 12
# 0      0         A/5 21171   7.2500   NaN        S          NaN
# 1      0          PC 17599  71.2833   C85        C          NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S          NaN
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.size
# Out:
# 2600

# %%
df.shape
# Out:
# (200, 13)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
